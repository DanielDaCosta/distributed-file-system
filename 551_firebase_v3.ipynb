# %% [markdown]
# ## DSCI 551 Project
#
# Create an emulation-based system for distributed file storage and parallel computation. <br>
# 1. Building an emulated distributed file system (EDFS) <br>
# - EDFS should support the following commands, similar to that in HDFS:
#     - mkdir: create a directory in file system, e.g., *mdkir /user/john
#     - ls: listing content of a given directory, e.g., *ls /user
#     - cat: display content of a file, e.g., *cat /user/john/hello.txt
#     - rm: remove a file from the file system, e.g., *rm /user/john/hello.txt
#     - put: uploading file to a file system, e.g., *put (car.csv, /user/john, k = # partitions)* will upload a file cars.csv to the directory /user/john in EDFS. **But note that the file should be stored in k partitions, and the file system should remember where the partitions are stored.** you should design a method to partition data. you may also have the user indicate the method, e.g., hashing on certain car attribute, in the put method.
#     - getPartitionLocations(file): this method will return the location of partitions of the file.
#     - readPartition(file, partition #): this method will return the content of partion # of the specified file. the portioned data will be needed in the second task for parallel processing.
# - **Note that EDFS should store the metadata about the file system** (similar to that in NameNode of HDFS, but much simplified). **Metadata include file system structure, attributes of files, and location of partitions storing the contents of files.** You can limit the type of files stored in the file system to certain format, e.g., .csv or JSON.
# <br><br>
#
# #### Google Firebase address : https://dsci551-project-52d43-default-rtdb.firebaseio.com/
# ### Statistical Capacity Indicators
# ###### Statistical Capacity Indicators provides information on various aspects of national statistical systems of developing countries, including an overall country-level statistical capacity indicator. Last Updated:02/03/2021
# #### Data from : https://databank.worldbank.org/source/statistical-capacity-indicators#

# %%
import pandas as pd
import numpy as np
import datetime
import requests
import json
import os
import re

firebase_url = 'https://dsci551-project-52d43-default-rtdb.firebaseio.com/'

def seek(path):
    if not re.search('.json', path):
        url = firebase_url + path + '.json'
        
    try:
        rget = requests.get(url)
        return rget
    except:
        print('ERROR')

# %% [markdown]
# ### MKDIR

# %%
def mkdir(path):
    if seek(path).json() is None:
        url = firebase_url + path + '.json'
        data = '{"test2":"2"}'
#         print (url)
        r = requests.put(url,data)
        print (r.url)
    else:
        print ('Directory ', path, ' already exists')

# requests.put('https://dsci551-project-52d43-default-rtdb.firebaseio.com/mk.json', '{"test":1}')

# %%
mkdir('DataNode') #Change to user input

# %% [markdown]
# ### LS

# %%
def ls(path):
    # ADDING "NameNode/root/" to Firebase request path
    if not re.search('NameNode/root', path):
        path = 'NameNode/root/' + path
    
    if seek(path).json() is not None:
        for key in seek(path).json().keys():
            print(key)
    else:
        print (" ")

# %%
ls('user') # Change to user input
# Out:
# Human_Capital_Index
# Stats_Cap_Ind

# %% [markdown]
# ### RM

# %%
def rm(path):
    if seek(path).json() is None:
        print ('Directory not found')
    else:
        url = firebase_url + path + '.json'
        d = requests.delete(url)
        if d.status_code == 200:
            print(path, 'was succefully deleted')

# %%
rm('NameNode/root/user')
rm('DataNode')

# %% [markdown]
# ### PUT

# %%
# function to get year columns
def is_year (c):
    return any(char.isdigit() for char in c)

def varlist (var):
    names = list()
    for v in var:
        key = re.sub(r'[^A-Za-z0-9 ]+', '', v).replace(" ", "_")
        names.append(key if key != "" else "invalid_key")
    return names

def varname (var):
    key = re.sub(r'[^A-Za-z0-9 ]+', '', var).replace(" ", "_")
    names = key if key != "" else "invalid_key"
    return names

def mtime():
#     to revert back
    #datetime.datetime.utcfromtimestamp(int(mtime)/1000).strftime('%Y-%-m-%-d %I:%M:%S') 
    return (datetime.datetime.now().timestamp()*1000)

def filesize(file): #file size in bytes
    return  os.path.getsize(file)

# %%
def record_partition(path, country, filename, url):
    try:
        npath = firebase_url + path + "/" + filename + "/partitions.json"
    #     print (npath ,":", url)
        mdata = {country : url}
        putMeta = requests.patch(npath, json.dumps(mdata))
        if putMeta.status_code == 400: print(country)
    #     print (putMeta)
    except:
        print (country)

def file_mdata(path, file, filename):
    npath = firebase_url + path + "/" + filename + ".json"
    mdata = {'ctime': mtime(),
             'name': file,
             'type': 'FILE',
             'filesize':filesize(file)}
    putMeta = requests.patch(npath, json.dumps(mdata))
    

# partition by Country (Original plan)
def put(file, path):
    filename = file.replace(".csv","")
    data = pd.read_csv(file).dropna()
    
    # change columns names
    new_columns = list()
    columns = data.columns
    for c in columns:
        if is_year(c):
            new_columns.append(c[:4])
        else:
            new_columns.append(c.replace(" ","_"))
    
    # change column names in dataframe
    data.columns = new_columns

    # creating a list of country names, country code, series name, series code, and years of the data collected
    cname = data.Country_Name.unique().tolist()
    sname = varlist(data.Series_Name.unique().tolist())
    years = [n for n in data.columns if n.isnumeric()]

    # replacement of symbols that are invalid in Firebase
#     cname2 = [sub.replace ('.','') for sub in cname]
#     sname2 = [sub.replace('/','-') for sub in sname]


    # creating dictinary to organize data into correct json format. 
    # added 'file name' to the dictionary to help differentiate data from different files
    dc = dict()
    for country in cname:
            c = varname(country)
#             dc[c]={ filename :dict(zip(years, [dict()]*len(years)))}
            dc[c]=dict(zip(years, [dict()]*len(years)))
            t = data[data['Country_Name'] == country]    
            for year in years:
                dc[c][year]=dict(zip(sname,t[year]))
                      
    if seek(path + '/' +filename).json() is None:
        for k, v in dc.items():
            url = firebase_url + 'DataNode/' + k + '/' + filename + '.json'
            putResponse = requests.put(url, json.dumps(dc[k]))
            if putResponse.status_code == 200:
                record_partition (path, k, filename, putResponse.url)
            else:
                print (file, 'failed to uploaded at partition', k)
        
        print (file, 'was succesfully uploaded to', path)
        
        file_mdata(path, file, filename)
        #add metadata information.
    else:
        print (file, "already exists in", path)
            
        
    return dc

# %%
filename = 'Stats_Cap_Ind.csv'
path = 'NameNode/root/user'
dc = put(filename, path)

# %%
filename = "datasets/Data_Extract_From_Statistical_Capacity_Indicators/42377300-c075-4554-a55f-41cd64c79126_Data.csv"
path = 'NameNode/root/user2'
dc = put(filename, path)
# Out:
# datasets/Data_Extract_From_Statistical_Capacity_Indicators/42377300-c075-4554-a55f-41cd64c79126_Data.csv was succesfully uploaded to NameNode/root/user2

# %% [markdown]
# ### getPartition

# %%
def getPartitionLocation(file):
    path = "NameNode/root/" + file + "/partitions"
    rpath = seek(path)
    partition = requests.get(rpath.url)
    pdict = partition.json()       
    
    return pdict

# %%
# file = "user/Stats_Cap_Ind"
# getPartitionLocation(file)

# %% [markdown]
# ### readPartition

# %%
def readPartition(file, partition):
    pdict = getPartitionLocation(file)
    url = pdict[partition]
    return requests.get(url).json()

# %%
readPartition('user/Stats_Cap_Ind', 'Argentina')
# Out:
# {'2004': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.66667',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '100',
#   'National_accounts_base_year': '1',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '92.2222222222222',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '96.66667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2005': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.66667',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '90',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '88.8888888888889',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '96.66667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2006': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.66667',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '90',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '88.8888888888889',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '96.66667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2007': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.66667',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '80',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '0',
#   'Overall_Average': '85.5555555555555',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '96.66667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2008': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '90',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '86.6666666666667',
#   'Per_capita_GDP_growth': '0.66667',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '90',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2009': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.66667',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '90',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '87.7777777777778',
#   'Per_capita_GDP_growth': '0.66667',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '93.33333',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2010': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '90',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '86.6666666666667',
#   'Per_capita_GDP_growth': '0.66667',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '90',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2011': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '90',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '85.5555555555555',
#   'Per_capita_GDP_growth': '0.33333',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '86.66667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2012': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '90',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '85.5555555555555',
#   'Per_capita_GDP_growth': '0.33333',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '86.66667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2013': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '0.66667',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '70',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '0',
#   'Overall_Average': '76.6666666666667',
#   'Per_capita_GDP_growth': '0.33333',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '0.66667',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2014': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '0.66667',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '0',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '100',
#   'National_accounts_base_year': '1',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '83.3333333333333',
#   'Per_capita_GDP_growth': '0.33333',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '70',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '0.66667',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2015': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '0.66667',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '1',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '100',
#   'National_accounts_base_year': '1',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '95.5555666666667',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '86.6667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '0.66667',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '100',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2016': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '1',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '0.66667',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0.5',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '90',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '88.8889',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '86.6667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '0.66667',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '90',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2017': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '0',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '0.66667',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0.5',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '1',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '80',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '85.5555666666667',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '86.6667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '0.66667',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '90',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2018': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '0',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '0',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '70',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '81.1111',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '93.3333',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2019': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '0',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '1',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '0',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '70',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '1',
#   'Overall_Average': '80',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '90',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '1',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '80',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'},
#  '2020': {'Access_to_water': '1',
#   'Agricultural_census': '1',
#   'Balance_of_payments_manual_in_use': '1',
#   'Child_malnutrition': '0.33333',
#   'Child_mortality': '1',
#   'Consumer_price_index_base_year': '0',
#   'External_debt_reporting_status': '1',
#   'Gender_equality': '0.66667',
#   'Government_finance_accounting': '1',
#   'HIVAIDS': '1',
#   'Health_survey': '0.5',
#   'Immunization': '1',
#   'Import_and_export_price_indexes': '0',
#   'Income_poverty': '1',
#   'Industrial_production_index': '1',
#   'Maternal_health': '1',
#   'Methodology_assessment_of_statistical_capacity_scale_0__100': '60',
#   'National_accounts_base_year': '0',
#   'National_immunization_coverage': '0',
#   'Overall_Average': '78.8889',
#   'Per_capita_GDP_growth': '1',
#   'Periodicity_and_timeliness_assessment_of_statistical_capacity_scale_0__100': '86.6667',
#   'Population_census': '1',
#   'Poverty_survey': '1',
#   'Primary_completion': '0.66667',
#   'Source_data_assessment_of_statistical_capacity_scale_0__100': '90',
#   'Special_Data_Dissemination_Standard': '1',
#   'UNESCO_reporting': '1',
#   'Vital_registration_system_coverage': '1'}}

# %% [markdown]
# ### CAT

# %%
def cat(path):
    file = path.replace('.csv','')
    pdict = getPartitionLocation(file)
    data = dict()
    for k,v in pdict.items():
        data[k] = requests.get(v).json()
    return data
    
    
# df = pd.DataFrame.from_dict(r.json())
# df.insert(0, 'Country', 'Argentina')

# %%
file = "user/Stats_Cap_Ind.csv"
data = cat(file)
df = pd.DataFrame.from_dict(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/danieldacosta/Documents/USC/dsci551/distributed-file-system/551_firebase_v3.ipynb Cell 25 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/danieldacosta/Documents/USC/dsci551/distributed-file-system/551_firebase_v3.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> file = "user/Stats_Cap_Ind.csv"
# ----> <a href='vscode-notebook-cell:/Users/danieldacosta/Documents/USC/dsci551/distributed-file-system/551_firebase_v3.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> data = cat(file)
#       <a href='vscode-notebook-cell:/Users/danieldacosta/Documents/USC/dsci551/distributed-file-system/551_firebase_v3.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> df = pd.DataFrame.from_dict(data)
#       <a href='vscode-notebook-cell:/Users/danieldacosta/Documents/USC/dsci551/distributed-file-system/551_firebase_v3.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> df
#
# NameError: name 'cat' is not defined

# %%
def ls(path: str) -> str:
    '''List files under path/.

    Args:
        path (str): path starting from NameNode/
    Returns:
        (str) Success or Error message
    '''
    slist = seek(f"NameNode/{path}")
    rlist = slist.json()

    result_list = []

    if type(rlist) == dict: # iterate over rlist if rlist != None
        for key, value in rlist.items():
            if key == "_": # empty directory
                continue
            if type(value) == dict: # if item is folder, add '/' to the end of thge string
                result_list.append(key + "/")
            else:
                result_list.append(key)
        output = 'empty' if not result_list else ', '.join(result_list)
    elif not rlist:
        output = f'Path {path} not found'
    else: 
        output = f'{path} is not a folder'
    
    return output

# %%
a = ls("root/")

# %%
a.split(",")
# Out:
# ['foo/', ' user/']

# %%
"empty".split(", ")
# Out:
# ['empty']

# %%
['foo/', 'user/', 'test']
# Out:
# ['foo/', 'user/', 'test']

# %%
def path_edfs_components(edfs_components: str) -> list:
    edfs_components = edfs_components.split(',')
    result_list = []
    for component in edfs_components:
        if '/' in component:
            
    [ for component in edfs_components if ]
    pass

# %%
{
    "folder": [\
        html.Div(children=f'''
            This is report: {folders}.\n
            This is department: {files}.
        '''),
        dcc.Link('Home', href=f"/?folders={variable_a + 1}&files={variable_a - 1}")
    ]
}

# %%
    html.Div(children=f'''
        This is report: {folders}.\n
        This is department: {files}.
    '''),
    dcc.Link('Home', href=f"/?folders={variable_a + 1}&files={variable_a - 1}")
